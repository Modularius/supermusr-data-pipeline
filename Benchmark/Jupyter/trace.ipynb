# %%
import matplotlib.pyplot as plt
EXPR = 0
TEST = 1
FRAME = 2
CHANNEL = 0

f = open(f"Temp/Experiment{EXPR}/Test{TEST}/output_f{FRAME}c{CHANNEL}_raw.csv", 'r')
tokens = [[float(x) for x in e.split(",")] for e in f.readlines()]
TIME_UNIT = 1.5378937007874016e-2
#tokens = tokens[:2000]
x = [e[0] for e in tokens]
y = [e[1] for e in tokens]
plt.plot(x,y)
